# %%
import pandas as pd

# %%
pd.read_csv('Teen_Mental_Health_Dataset.csv')
# Out:
#       age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0      14    male                       7.9      Instagram          7.4
# 1      19  female                       1.9         TikTok          8.0
# 2      17  female                       1.3      Instagram          7.6
# 3      15    male                       7.4         TikTok          6.9
# 4      15  female                       4.7           Both          4.9
# ...   ...     ...                       ...            ...          ...
# 1195   18  female                       6.8      Instagram          6.6
# 1196   16    male                       2.3           Both          8.0
# 1197   14  female                       1.7           Both          8.7
# 1198   15    male                       3.9           Both          8.5
# 1199   16  female                       4.7         TikTok          6.5
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# 0                          2.9                  3.01                1.5
# 1                          2.9                  3.22                0.8
# 2                          0.5                  3.92                0.0
# 3                          1.6                  3.48                0.8
# 4                          3.0                  2.37                1.4
# ...                        ...                   ...                ...
# 1195                       2.0                  2.76                1.0
# 1196                       1.9                  2.12                0.4
# 1197                       0.7                  3.98                0.8
# 1198                       2.1                  3.19                0.6
# 1199                       1.0                  2.91                0.9
#
#      social_interaction_level  stress_level  anxiety_level  addiction_level  \
# 0                         low             2              2                1
# 1                        high             8              1               10
# 2                        high             2              4                2
# 3                      medium             1              7                9
# 4                      medium             3              5                2
# ...                       ...           ...            ...              ...
# 1195                      low             3              4                4
# 1196                     high             7              4                4
# 1197                     high             1              1                1
# 1198                     high             7              9                9
# 1199                   medium             5              7                3
#
#       depression_label
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 1195                 0
# 1196                 0
# 1197                 0
# 1198                 0
# 1199                 0
#
# [1200 rows x 13 columns]

# %%
  import numpy as np

# %%
df=pd.read_csv('final_placement_dataset.csv')

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.shape
# Out:
# (100, 3)

# %% [markdown]
# - 1. preprocess + eda + feature selectin
# - 2. extract input and output columns
# - 3. scale the value
# - 4. train test split
# - 5. train the model
# - 6. evaluate the model
# - 7. deploy the model

# %%
df.info
# Out:
# <bound method DataFrame.info of     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
X=df.iloc[:,0:2]
Y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 54   6.4  141.0
# 69   8.5  120.0
# 61   7.3  137.0
# 75   4.8  169.0
# 36   5.7  140.0
# ..   ...    ...
# 93   6.8  112.0
# 62   6.0  102.0
# 55   7.8  114.0
# 70   6.3  127.0
# 99   6.2  113.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 34   4.8  163.0
# 41   5.4  114.0
# 46   5.3  114.0
# 92   5.2  110.0
# 88   4.4  149.0
# 4    5.8  142.0
# 84   5.7  169.0
# 63   6.3  128.0
# 56   6.1   65.0
# 28   5.2   90.0

# %%
Y_train
# Out:
# 54    1
# 69    1
# 61    1
# 75    0
# 36    0
#      ..
# 93    1
# 62    0
# 55    1
# 70    1
# 99    1
# Name: placement, Length: 90, dtype: int64

# %%
Y_test
# Out:
# 34    0
# 41    0
# 46    0
# 92    0
# 88    0
# 4     0
# 84    0
# 63    1
# 56    0
# 28    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.29575234,  0.43122664],
#        [ 2.09308968, -0.08591698],
#        [ 1.06603977,  0.3327231 ],
#        [-1.07364755,  1.12075148],
#        [-0.30336011,  0.40660076],
#        [ 0.38133983, -0.8246936 ],
#        [ 1.32280225, -0.84931948],
#        [-0.21777262,  1.04687382],
#        [ 0.46692732,  0.35734898],
#        [-1.24482253,  0.55435608],
#        [-0.56012259, -0.40605352],
#        [-0.98806006, -1.53884432],
#        [-1.41599752, -2.00673617],
#        [ 0.63810231, -0.01203932],
#        [ 1.66515222, -1.09557835],
#        [ 0.38133983,  0.16034189],
#        [-2.35745994,  1.4655139 ],
#        [ 0.80927729,  0.38197487],
#        [-0.73129758,  0.20959366],
#        [-0.90247256, -1.48959255],
#        [-0.81688507,  0.11109011],
#        [-2.18628495,  2.69680825],
#        [-0.98806006,  0.77598906],
#        [-0.98806006,  1.78565043],
#        [ 0.80927729,  1.2685068 ],
#        [ 0.7236898 ,  0.35734898],
#        [ 1.75073971,  0.62823374],
#        [ 1.23721476,  0.84986672],
#        [ 0.03898986,  0.80061495],
#        [ 0.63810231,  0.43122664],
#        [-1.75834749, -0.57843472],
#        [ 0.55251481,  1.44088801],
#        [-0.30336011,  0.20959366],
#        [-0.30336011,  0.48047842],
#        [ 1.32280225,  0.11109011],
#        [-0.90247256, -0.80006771],
#        [ 0.38133983,  0.8991185 ],
#        [-0.81688507,  1.29313269],
#        [-0.04659763, -1.93285851],
#        [ 0.03898986, -0.50455706],
#        [-0.90247256, -0.13516876],
#        [ 0.80927729, -0.28292408],
#        [ 1.23721476, -1.53884432],
#        [-0.73129758,  0.92374439],
#        [-0.04659763,  0.62823374],
#        [-1.07364755, -0.28292408],
#        [-1.50158501,  1.88415398],
#        [-1.75834749, -1.1940819 ],
#        [-1.07364755,  0.43122664],
#        [-0.13218513, -0.4306794 ],
#        [-1.15923504, -0.89857126],
#        [ 0.21016484, -0.50455706],
#        [-0.04659763,  0.01258656],
#        [ 0.80927729,  1.85952809],
#        [-0.98806006,  0.67748551],
#        [ 1.06603977, -0.92319714],
#        [ 1.9219147 ,  1.09612559],
#        [-1.15923504, -0.0612911 ],
#        [ 0.80927729, -1.46496666],
#        [ 0.7236898 , -0.67693827],
#        [ 1.06603977, -1.80972908],
#        [ 1.15162726,  0.20959366],
#        [ 0.03898986,  0.20959366],
#        [-0.56012259,  0.28347132],
#        [ 0.03898986, -1.04632658],
#        [ 0.38133983, -2.12986561],
#        [ 0.63810231, -0.8246936 ],
#        [-0.81688507, -1.41571488],
#        [-1.15923504, -1.7604773 ],
#        [-0.73129758,  2.47517527],
#        [ 0.89486479,  0.67748551],
#        [ 0.46692732, -0.08591698],
#        [ 0.55251481,  0.75136318],
#        [-0.98806006, -0.08591698],
#        [-0.04659763, -1.41571488],
#        [-1.84393498, -0.35680174],
#        [ 1.23721476,  0.16034189],
#        [ 0.29575234, -0.18442053],
#        [-0.98806006,  0.25884543],
#        [ 0.7236898 ,  0.38197487],
#        [ 0.89486479, -1.85898085],
#        [ 1.06603977, -0.18442053],
#        [-0.64571008, -0.0612911 ],
#        [-0.56012259,  0.38197487],
#        [ 1.75073971,  1.04687382],
#        [ 0.63810231, -0.28292408],
#        [-0.04659763, -0.52918295],
#        [ 1.49397724, -0.23367231],
#        [ 0.21016484,  0.08646423],
#        [ 0.12457735, -0.25829819]])

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.07364755,  0.97299616],
#        [-0.56012259, -0.23367231],
#        [-0.64571008, -0.23367231],
#        [-0.73129758, -0.33217585],
#        [-1.41599752,  0.62823374],
#        [-0.21777262,  0.45585253],
#        [-0.30336011,  1.12075148],
#        [ 0.21016484,  0.11109011],
#        [ 0.03898986, -1.44034077],
#        [-0.73129758, -0.8246936 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=clf.predict(X_test)

# %%
Y_test
# Out:
# 34    0
# 41    0
# 46    0
# 92    0
# 88    0
# 4     0
# 84    0
# 63    1
# 56    0
# 28    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\ritvika jain\ai\venv\lib\site-packages (from mlxtend) (1.17.0)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\ritvika jain\ai\venv\lib\site-packages (from mlxtend) (2.4.1)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\ritvika jain\ai\venv\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\ritvika jain\ai\venv\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\ritvika jain\ai\venv\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\ritvika jain\ai\venv\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ritvika jain\ai\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritvika jain\ai\venv\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ritvika jain\ai\venv\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\ritvika jain\ai\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\ritvika jain\ai\venv\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ----------------------- ---------------- 0.8/1.4 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.0 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.24.0
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))

# %%
d
